# %%
import pandas as pd

# %%
cast=pd.read_csv('cast.csv')
cast.head(5)
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
df = pd.read_csv('titles.csv')
df.head(5)
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
mov=df.title.count()

print('No of Total movies listed : ', mov)
# Out:
# No of Total movies listed :  230621

# %%
total=df.title.nunique()

print('No of Total unique movies listed : ', total)
# Out:
# No of Total unique movies listed :  210938

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
df.sort_values('year').head(2)
# Out:
#                      title  year
# 176477          Miss Jerry  1894
# 213694  The Startled Lover  1898

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
df.loc[df['title']=='Hamlet']
# Out:
#          title  year
# 5969    Hamlet  1948
# 45010   Hamlet  1990
# 46365   Hamlet  1910
# 91506   Hamlet  1976
# 93696   Hamlet  1987
# 93894   Hamlet  2000
# 97869   Hamlet  1921
# 102208  Hamlet  2011
# 121837  Hamlet  1969
# 127468  Hamlet  1954
# 165217  Hamlet  1913
# 167748  Hamlet  2015
# 174816  Hamlet  2009
# 181662  Hamlet  1964
# 199837  Hamlet  1996
# 208366  Hamlet  1911
# 219855  Hamlet  1973
# 221923  Hamlet  2014

# %%
print("No. of movies have the title 'Hamlet':")
df.loc[df['title']=='Hamlet'].count()
# Out:
# No. of movies have the title 'Hamlet':
# title    18
# year     18
# dtype: int64

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
df.loc[df['title']== "North by Northwest"]
# Out:
#                      title  year
# 138297  North by Northwest  1959

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
df.loc[df['title']=='Hamlet'].sort_values('year').head(1)
# Out:
#         title  year
# 46365  Hamlet  1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
df.loc[df['title']=="Treasure Island"].sort_values('year')
# Out:
#                   title  year
# 204540  Treasure Island  1918
# 50896   Treasure Island  1920
# 189691  Treasure Island  1934
# 96259   Treasure Island  1950
# 59186   Treasure Island  1972
# 110576  Treasure Island  1973
# 203909  Treasure Island  1985
# 178072  Treasure Island  1999

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
df.loc[df['year']==1950]
# Out:
#                       title  year
# 70         Campo O' Donnell  1950
# 89         Botta e risposta  1950
# 232                  Madari  1950
# 552     Un certain monsieur  1950
# 1004      Vom Teufel gejagt  1950
# ...                     ...   ...
# 229550         Dwie brygady  1950
# 229637   La negra Angustias  1950
# 229697                Jogan  1950
# 230233         Rasuna valea  1950
# 230300     Thyella sto faro  1950
#
# [1093 rows x 2 columns]

# %%
df.loc[df['year']==1950].count()
# Out:
# title    1093
# year     1093
# dtype: int64

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
df.loc[df['year']==1960]
# Out:
#                               title  year
# 103                 Cone of Silence  1960
# 324                   The Challenge  1960
# 450         Dos hijos desobedientes  1960
# 892               Caught in the Net  1960
# 1002            Un militare e mezzo  1960
# ...                             ...   ...
# 229932                        India  1960
# 229952                    Wu cai lu  1960
# 229983              Walang Pangalan  1960
# 230188                  Fuefukigawa  1960
# 230398  Il peccato degli anni verdi  1960
#
# [1496 rows x 2 columns]

# %%
df.loc[df['year']==1960].count()
# Out:
# title    1496
# year     1496
# dtype: int64

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
df1=pd.read_csv('titles.csv', index_col='year')
df1.loc[[1950,1951,1952,1953,1954,1955,1956,1957,1958,1959]]
# Out:
#                           title
# year
# 1950           Campo O' Donnell
# 1950           Botta e risposta
# 1950                     Madari
# 1950        Un certain monsieur
# 1950          Vom Teufel gejagt
# ...                         ...
# 1959  Chelovek s planety Zemlya
# 1959          Itsuka kita michi
# 1959               Cara de Goma
# 1959        Himmel och pannkaka
# 1959           Some Like It Hot
#
# [12656 rows x 1 columns]

# %%
df1.loc[[1950,1951,1952,1953,1954,1955,1956,1957,1958,1959]].count()
# Out:
# title    12656
# dtype: int64

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
df.loc[df['title']=='Batman']
# Out:
#         title  year
# 55577  Batman  1989
# 74047  Batman  1943

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
cast.loc[cast['title']=="Inception"]
# Out:
#              title  year                  name     type  \
# 94333    Inception  2010  Michael (III) August    actor
# 143138   Inception  2010          Peter Basham    actor
# 176819   Inception  2010          Tom Berenger    actor
# 190249   Inception  2010              Ken Bhan    actor
# 250191   Inception  2010        Virgile Bramly    actor
# ...            ...   ...                   ...      ...
# 3238950  Inception  2010            Ellen Page  actress
# 3292669  Inception  2010        Nicole Pulliam  actress
# 3319073  Inception  2010    Lisa (II) Reynolds  actress
# 3325768  Inception  2010         Talulah Riley  actress
# 3560127  Inception  2010        Shannon Welles  actress
#
#                      character     n
# 94333            LAX Passenger   NaN
# 143138   Fischer's Jet Captain  44.0
# 176819                Browning   8.0
# 190249        Mombasan Gambler   NaN
# 250191          Bridge Sub Con  29.0
# ...                        ...   ...
# ...

# %%
print("No.of roles were there in the movie 'Inception'")

cast.loc[cast['title']=="Inception"].count()
# Out:
# No.of roles were there in the movie 'Inception'
# title        77
# year         77
# name         77
# type         77
# character    77
# n            51
# dtype: int64

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
cast.loc[cast['title']=='Inception']
# Out:
#              title  year                  name     type  \
# 94333    Inception  2010  Michael (III) August    actor
# 143138   Inception  2010          Peter Basham    actor
# 176819   Inception  2010          Tom Berenger    actor
# 190249   Inception  2010              Ken Bhan    actor
# 250191   Inception  2010        Virgile Bramly    actor
# ...            ...   ...                   ...      ...
# 3238950  Inception  2010            Ellen Page  actress
# 3292669  Inception  2010        Nicole Pulliam  actress
# 3319073  Inception  2010    Lisa (II) Reynolds  actress
# 3325768  Inception  2010         Talulah Riley  actress
# 3560127  Inception  2010        Shannon Welles  actress
#
#                      character     n
# 94333            LAX Passenger   NaN
# 143138   Fischer's Jet Captain  44.0
# 176819                Browning   8.0
# 190249        Mombasan Gambler   NaN
# 250191          Bridge Sub Con  29.0
# ...                        ...   ...
# ...

# %%
print('No. ofroles in the movie "Inception" are NOT ranked by an "n" value: \n')

cast.loc[cast['title']=='Inception'].n.isnull().sum()
# Out:
# No. ofroles in the movie "Inception" are NOT ranked by an "n" value:
# 26

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
cast.loc[cast['title']=='Inception'].dropna()
# Out:
#              title  year                  name     type  \
# 143138   Inception  2010          Peter Basham    actor
# 176819   Inception  2010          Tom Berenger    actor
# 250191   Inception  2010        Virgile Bramly    actor
# 314663   Inception  2010         Michael Caine    actor
# 321091   Inception  2010          Earl Cameron    actor
# 417982   Inception  2010         Nicolas Clerc    actor
# 428199   Inception  2010        Adam (IV) Cole    actor
# 498708   Inception  2010    Jean-Michel Dagory    actor
# 569504   Inception  2010     Leonardo DiCaprio    actor
# 684215   Inception  2010             Russ Fega    actor
# 711192   Inception  2010      Mark Fleischmann    actor
# 779284   Inception  2010        Michael Gaston    actor
# 783405   Inception  2010       Johnathan Geare    actor
# 802478   Inception  2010         Carl Gilliard    actor
# 803728   Inception  2010           Jack Gilroy    actor
# 829338   Inception  2010  Joseph Gordon-Levitt    actor
# ...

# %%
print("no. of roles in movie 'Inception' did receive 'n' value: \n")

cast.loc[cast['title']=='Inception'].dropna().count()
# Out:
# no. of roles in movie 'Inception' did receive 'n' value:
# title        51
# year         51
# name         51
# type         51
# character    51
# n            51
# dtype: int64

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
cast.loc[cast['title']=='North by Northwest'].dropna()
# Out:
#                       title  year                  name     type  \
# 198496   North by Northwest  1959          Edward Binns    actor
# 343701   North by Northwest  1959        Leo G. Carroll    actor
# 447893   North by Northwest  1959       Philip Coolidge    actor
# 642085   North by Northwest  1959     Robert Ellenstein    actor
# 840374   North by Northwest  1959            Cary Grant    actor
# 1229083  North by Northwest  1959         Martin Landau    actor
# 1334726  North by Northwest  1959             Ken Lynch    actor
# 1404704  North by Northwest  1959           James Mason    actor
# 1454363  North by Northwest  1959         Patrick McVey    actor
# 1634552  North by Northwest  1959           Philip Ober    actor
# 1746383  North by Northwest  1959          Edward Platt    actor
# 2212083  North by Northwest  1959          Les Tremayne    actor
# 2357939  North by Northwest  1959         Adam Williams    actor
# ...

# %%
cast.loc[cast['title']=='North by Northwest'].dropna().count()
# Out:
# title        16
# year         16
# name         16
# type         16
# character    16
# n            16
# dtype: int64

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
cast.loc[(cast['title']=='Sleuth')&(cast['year']==1972)]
# Out:
#           title  year                name     type  \
# 314691   Sleuth  1972       Michael Caine    actor
# 360365   Sleuth  1972      Alec Cawthorne    actor
# 1396572  Sleuth  1972        Teddy Martin    actor
# 1412647  Sleuth  1972  John (II) Matthews    actor
# 1644328  Sleuth  1972    Laurence Olivier    actor
# 2619278  Sleuth  1972  Eve (III) Channing  actress
#
#                           character    n
# 314691                  Milo Tindle  2.0
# 360365            Inspector Doppler  3.0
# 1396572      Police Constable Higgs  6.0
# 1412647  Detective Sergeant Tarrant  4.0
# 1644328                 Andrew Wyke  1.0
# 2619278             Marguerite Wyke  5.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
cast.loc[(cast['title']=='Sleuth')&(cast['year']==2007)]
# Out:
#           title  year                 name     type          character    n
# 250297   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 314692   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 360366   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 1246855  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1741124  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 2619277  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3223502  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
cast.loc[(cast['title']=='Hamlet')&(cast['year']==1921)]
# Out:
#           title  year                    name     type         character    n
# 7438     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 442224   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 535307   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1095274  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 2106367  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2289163  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2562876  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 2935728  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 3209199  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0

# %%
cast.loc[(cast['title']=='Hamlet')&(cast['year']==1921)].count()
# Out:
# title        9
# year         9
# name         9
# type         9
# character    9
# n            9
# dtype: int64

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
cast.loc[(cast['title']=='Hamlet')&(cast['year']==1996)]
# Out:
#           title  year                    name     type  \
# 1615     Hamlet  1996              Riz Abbasi    actor
# 92106    Hamlet  1996    Richard Attenborough    actor
# 152349   Hamlet  1996     Simon Russell Beale    actor
# 206181   Hamlet  1996         David (V) Blair    actor
# 211111   Hamlet  1996           Brian Blessed    actor
# 241315   Hamlet  1996      Christopher Bowles    actor
# 250281   Hamlet  1996         Kenneth Branagh    actor
# 262368   Hamlet  1996          Richard Briers    actor
# 283598   Hamlet  1996          Michael Bryant    actor
# 307699   Hamlet  1996            Peter Bygott    actor
# 331657   Hamlet  1996       Kenneth W Caravan    actor
# 482982   Hamlet  1996           Billy Crystal    actor
# 500005   Hamlet  1996           Charles Daish    actor
# 555725   Hamlet  1996        G?rard Depardieu    actor
# 577284   Hamlet  1996          Reece Dinsdale    actor
# 582748   Hamlet  1996                Ken Dodd    actor
# ...

# %%
cast.loc[(cast['title']=='Hamlet')&(cast['year']==1996)].count()
# Out:
# title        54
# year         54
# name         54
# type         54
# character    54
# n            46
# dtype: int64

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
cast.loc[cast['character']=='Hamlet']
# Out:
#                                  title  year               name     type  \
# 6003                             Sugar  2008       Hamlet Abreu    actor
# 94018                  Top of the Town  1937        Mischa Auer    actor
# 120093             The Sound of Spying  2014      Jonathan Ball    actor
# 154451                Suivez cet avion  1989  Fran?ois Beaulieu    actor
# 154754          Nous sommes les autres  2017       Marc Beaupr?    actor
# ...                                ...   ...                ...      ...
# 2517189                       Hamlet_X  2003       Meret Becker  actress
# 2622924  Bill Shakespeare in Hollywood  2011    Rafika Chawishe  actress
# 2825750    Intikam Melegi/Kadin Hamlet  1976        Fatma Girik  actress
# 3209199                         Hamlet  1921       Asta Nielsen  actress
# 3256505                         Hamlet  2015       Maxine Peake  actress
#
#         character     n
# 6003       Hamlet  58.0
# 94018      Hamlet   6.0
# ...

# %%
cast.loc[cast['character']=='Hamlet'].count()
# Out:
# title        91
# year         91
# name         91
# type         91
# character    91
# n            55
# dtype: int64

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
cast.loc[cast['character']=='Ophelia']
# Out:
#                                    title  year                  name     type  \
# 238855        The Merry Maids of Madness  2016           Amy Bourque    actor
# 395196                    Jake Gets Paid  2009        Josie Chisholm    actor
# 453835                        Inoperable  2016       Crystal Cordero    actor
# 835461   Dogg's Hamlet, Cahoot's Macbeth  2005         Lucas Grabeel    actor
# 1315145                               11  2014   Catherine (IV) Lord    actor
# ...                                  ...   ...                   ...      ...
# 3538349         Hamlet, Son of a Kingpin  2015        Ingrid Vollset  actress
# 3551691                         D.C. Cab  1983       Marsha Warfield  actress
# 3552384                         Creature  2011  Jennifer Lynn Warren  actress
# 3562331                           Hamlet  2015       Katie (II) West  actress
# 3578802                           Hamlet  1996          Kate Winslet  actress
#
#         character     n
# ...

# %%
cast.loc[cast['character']=='Ophelia'].count()
# Out:
# title        111
# year         111
# name         111
# type         111
# character    111
# n             59
# dtype: int64

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
cast.loc[cast['character']=='The Dude']
# Out:
#                                   title  year                  name   type  \
# 261792                 The Big Lebowski  1998          Jeff Bridges  actor
# 326893               Terms & Conditions  2015           Jordan Cann  actor
# 480810                         Stranger  2000         Scott Crowell  actor
# 549887           Pizza Man vs. the Dude  2004        Chris DeMarcus  actor
# 588962                      Sweepstakes  1931           Mike Donlin  actor
# 607151                    Self Helpless  2010        Devin The Dude  actor
# 1051244  Jay and Silent Bob Strike Back  2001   Matthew (XIX) James  actor
# 1098711                   Explicit Ills  2008    Christopher Kadish  actor
# 1317786                 American Idiots  2013      Jason Loughridge  actor
# 1336484             The Winds of Autumn  1976           Steve Lyons  actor
# 1458465                         The Liq  2016        Mark Alan Meek  actor
# ...

# %%
cast.loc[cast['character']=='The Dude'].count()
# Out:
# title        18
# year         18
# name         18
# type         18
# character    18
# n            12
# dtype: int64

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
cast.loc[cast['character']=='The Stranger']
# Out:
#                             title  year                       name     type  \
# 24819                       Theeb  2014  Hassan Mutlag Al-Maraiyeh    actor
# 34302              My Time to Die  2014       Vincent H. Alexander    actor
# 64774                    Get Mean  1975               Tony Anthony    actor
# 64777    Lo straniero di silenzio  1968               Tony Anthony    actor
# 64779      Un dollaro tra i denti  1967               Tony Anthony    actor
# ...                           ...   ...                        ...      ...
# 3068419              The Stranger  1995                 Kathy Long  actress
# 3081837            Ever Since Eve  1921                Ethel Lynne  actress
# 3256243              Weitertanzen  2008             Rosa Maria Paz  actress
# 3276867               The Godsend  1980           Angela Pleasence  actress
# 3407234                Motherland  1927            Dorinea Shirley  actress
#
#             character    n
# 24819    The Stranger  3.0
# ...

# %%
cast.loc[cast['character']=='The Stranger'].count()
# Out:
# title        208
# year         208
# name         208
# type         208
# character    208
# n            130
# dtype: int64

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
cast.loc[cast['name']=='Sidney Poitier']
# Out:
#                                 title  year            name   type  \
# 1751059               A Patch of Blue  1965  Sidney Poitier  actor
# 1751060         A Piece of the Action  1977  Sidney Poitier  actor
# 1751061           A Raisin in the Sun  1961  Sidney Poitier  actor
# 1751062               A Warm December  1973  Sidney Poitier  actor
# 1751063             All the Young Men  1960  Sidney Poitier  actor
# 1751064                Band of Angels  1957  Sidney Poitier  actor
# 1751065             Blackboard Jungle  1955  Sidney Poitier  actor
# 1751066                  Brother John  1971  Sidney Poitier  actor
# 1751067         Buck and the Preacher  1972  Sidney Poitier  actor
# 1751068      Cry, the Beloved Country  1951  Sidney Poitier  actor
# 1751069                Duel at Diablo  1966  Sidney Poitier  actor
# 1751070              Edge of the City  1957  Sidney Poitier  actor
# 1751071               For Love of Ivy  1968  Sidney Poitier  actor
# ...

# %%
cast.loc[cast['name']=='Sidney Poitier'].count()
# Out:
# title        43
# year         43
# name         43
# type         43
# character    43
# n            42
# dtype: int64

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
cast.loc[cast['name']=='Judi Dench']
# Out:
#                                                      title  year        name  \
# 2703455                              84 Charing Cross Road  1987  Judi Dench
# 2703456                                  A Handful of Dust  1988  Judi Dench
# 2703457                          A Midsummer Night's Dream  1968  Judi Dench
# 2703458                                 A Room with a View  1985  Judi Dench
# 2703459                                  A Study in Terror  1965  Judi Dench
# 2703460             Angelina Ballerina: Angelina Sets Sail  2006  Judi Dench
# 2703461                                      Casino Royale  2006  Judi Dench
# 2703462                                           Chocolat  2000  Judi Dench
# 2703463                                          Dead Cert  1974  Judi Dench
# 2703464                                    Die Another Day  2002  Judi Dench
# 2703465                                             Doogal  2006  Judi Dench
# ...

# %%
cast.loc[cast['name']=='Judi Dench'].count()
# Out:
# title        55
# year         55
# name         55
# type         55
# character    55
# n            48
# dtype: int64

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
cast.loc[(cast['n']==2)&(cast['name']=='Cary Grant')&(cast['year']==1940)]
# Out:
#                    title  year        name   type character    n
# 840371  My Favorite Wife  1940  Cary Grant  actor      Nick  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
cast.loc[(cast['name']=='Cary Grant')&(cast['year']==1940)]
# Out:
#                           title  year        name   type           character  \
# 840353          His Girl Friday  1940  Cary Grant  actor        Walter Burns
# 840371         My Favorite Wife  1940  Cary Grant  actor                Nick
# 840397  The Howards of Virginia  1940  Cary Grant  actor         Matt Howard
# 840399   The Philadelphia Story  1940  Cary Grant  actor  C. K. Dexter Haven
#
#           n
# 840353  1.0
# 840371  2.0
# 840397  1.0
# 840399  1.0

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
cast.loc[(cast['type']=='actor')&(cast['year']==1950)]
# Out:
#                              title  year            name   type  \
# 266               Palletoori Pilla  1950  Subba Rao A.V.  actor
# 429                   Hallin Janne  1950  Kosti Aaltonen  actor
# 430                   Hallin Janne  1950  Kosti Aaltonen  actor
# 1481     Fortunes of Captain Blood  1950  Abdullah Abbas  actor
# 1497          The Baron of Arizona  1950  Abdullah Abbas  actor
# ...                            ...   ...             ...    ...
# 2439128           Restaurant Intim  1950   Steinar ?ster  actor
# 2439164            Den vita katten  1950     Alf ?stlund  actor
# 2439166       Flicka och hyacinter  1950     Alf ?stlund  actor
# 2439170         Medan staden sover  1950     Alf ?stlund  actor
# 2439172           Restaurant Intim  1950     Alf ?stlund  actor
#
#                 character     n
# 266         Kampanna Dora   4.0
# 429                 Rosvo   NaN
# 430               Vartija   NaN
# 1481          Crew Member   NaN
# ...

# %%
cast.loc[(cast['type']=='actor')&(cast['year']==1950)].count()
# Out:
# title        16512
# year         16512
# name         16512
# type         16512
# character    16512
# n             7535
# dtype: int64

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
cast.loc[(cast['type']=='actress')&(cast['year']==1950)]
# Out:
#                            title  year               name     type  \
# 2440031   A Woman of Distinction  1950  Lucienne & Ashour  actress
# 2440033          Chain Lightning  1950  Lucienne & Ashour  actress
# 2440825        A Life of Her Own  1950     Dorothy Abbott  actress
# 2440829       Annie Get Your Gun  1950     Dorothy Abbott  actress
# 2440832            Copper Canyon  1950     Dorothy Abbott  actress
# ...                          ...   ...                ...      ...
# 3610440         La vida en broma  1950      Dalia ??iguez  actress
# 3610445             Quinto patio  1950      Dalia ??iguez  actress
# 3610681  Harukanari haha no kuni  1950      Chiharu ?tomo  actress
# 3610827     Anderssonskans Kalle  1950   Ingrid ?stergren  actress
# 3611137       Akdeniz korsanlari  1950    Muazzez ?lkerer  actress
#
#                                  character    n
# 2440031                     Apache Dancers  NaN
# 2440033                     Apache Dancers  NaN
# ...

# %%
cast.loc[(cast['type']=='actress')&(cast['year']==1950)].count()
# Out:
# title        5494
# year         5494
# name         5494
# type         5494
# character    5494
# n            3116
# dtype: int64

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
cast.loc[(cast['n']==1)&(cast['year']==1980)]
# Out:
#                                      title  year                 name  \
# 1221                         Il pap'occhio  1980    Diego Abatantuono
# 1374               Athkiya' laken aghbiya'  1980         Rushdy Abaza
# 2384                     El Banat Ayza Eih  1980   Mahmoud Abdel Aziz
# 2781                             Airplane!  1980  Kareem Abdul-Jabbar
# 4385                    Nakalnya anak-anak  1980        Zainal Abidin
# ...                                    ...   ...                  ...
# 3598555                           Demented  1980         Sallee Young
# 3599288                      Majimak milae  1980             Ji-in Yu
# 3600558               Aduh aduh mana tahan  1980          Diana Yusuf
# 3610588    Jokosei: natsu hiraku kuchiburu  1980            Ayako ?ta
# 3610590  Kairaku gakuen: kinjirareta asobi  1980            Ayako ?ta
#
#             type        character    n
# 1221       actor   Padre Gabriele  1.0
# 1374       actor            Hamdi  1.0
# ...

# %%
cast.loc[(cast['n']==1)&(cast['year']==1980)].count()
# Out:
# title        1143
# year         1143
# name         1143
# type         1143
# character    1143
# n            1143
# dtype: int64

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
cast.loc[(cast['n']!=1)&(cast['year']==1980)]
# Out:
#                                                     title  year  \
# 195                         Cheech and Chong's Next Movie  1980
# 423                                          Aurinkotuuli  1980
# 472      Bob Hope's All-Star Look at TV's Prime Time Wars  1980
# 597                                           Raging Bull  1980
# 998                                                Afanti  1980
# ...                                                   ...   ...
# 3610679                                  Tsigoineruwaizen  1980
# 3610867                                             Akrep  1980
# 3610915                                      Gerzek Saban  1980
# 3610960                                Kizi da anasi gibi  1980
# 3610972                                       Banker Bilo  1980
#
#                    name     type          character     n
# 195            Bobby A.    actor            Doorman  33.0
# 423      Jouko Aaltonen    actor     Man on lecture  12.0
# ...

# %%
cast.loc[(cast['n']!=1)&(cast['year']==1980)].count()
# Out:
# title        21648
# year         21648
# name         21648
# type         21648
# character    21648
# n            17421
# dtype: int64

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
cast.loc[cast['year']==1980]
# Out:
#                                                     title  year  \
# 195                         Cheech and Chong's Next Movie  1980
# 423                                          Aurinkotuuli  1980
# 472      Bob Hope's All-Star Look at TV's Prime Time Wars  1980
# 597                                           Raging Bull  1980
# 998                                                Afanti  1980
# ...                                                   ...   ...
# 3610679                                  Tsigoineruwaizen  1980
# 3610867                                             Akrep  1980
# 3610915                                      Gerzek Saban  1980
# 3610960                                Kizi da anasi gibi  1980
# 3610972                                       Banker Bilo  1980
#
#                    name     type          character     n
# 195            Bobby A.    actor            Doorman  33.0
# 423      Jouko Aaltonen    actor     Man on lecture  12.0
# ...

# %%
print('No. of roles through 1980 were minor enough that they did not warrant a numeric "n" rank:')

cast.loc[cast['year']==1980].n.isnull().sum()
# Out:
# No. of roles through 1980 were minor enough that they did not warrant a numeric "n" rank:
# 4227
